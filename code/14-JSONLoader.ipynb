# %%
from langchain_community.document_loaders import JSONLoader

loader = JSONLoader(
    file_path="./data/people.json",
    jq_schema=".[].name",
    text_content=False,
    json_lines=False,
)


documents = loader.load()

print(documents)
# Out:
# [Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 1}, page_content='Yiming Zhang'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 2}, page_content='Xinyi Liu'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 3}, page_content='Haoran Chen'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 4}, page_content='Yutong Wang'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 5}, page_content='Zihan Li'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 6}, page_content='Mengqi Zhao'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 7}, page_content='Jiacheng Sun'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 8}, page_content='Siyu Zhou'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 9}, page_content='Kangrui Wu'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 10}, page_content='Ruoxi Xu'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 11}, page_content='Tianyu Huang'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 12}, page_content='Yuxuan Gao'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 13}, page_content='Bo Yang'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 14}, page_content='Shiqi Tang'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 15}, page_content='Zehao Lin'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 16}, page_content='Yihan Deng'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 17}, page_content='Chengxiang He'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 18}, page_content='Yue Chen'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 19}, page_content='Junhao Guo'), Document(metadata={'source': '/Users/zizhengli/Documents/LLM-playground/code/data/people.json', 'seq_num': 20}, page_content='Hanxuan Ma')]
