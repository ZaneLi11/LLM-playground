# %%
from openai import OpenAI


client = OpenAI(
    api_key="ollama_local",
    base_url="http://localhost:11434/v1"
)
def chat_with_deepseek():
    print("calling local model...\n")
    try:
        response = client.chat.completions.create(
            model="deepseek-r1:8b", 
            messages=[
                {"role": "user", "content": "who are u?"}
            ],
        )
        
        reply = response.choices[0].message.content

        print("Deepseek's response:")
        print(reply)

    except Exception as e:
        print(f"Error: {e}")

# %%
chat_with_deepseek()
# Out:
# calling local model...
#
# Deepseek's response:
# Hey there! 😊 I'm Assistant—your friendly AI companion here to help you with questions, explain things, solve problems, and maybe even have a good conversation. Think of me as your knowledgeable sidekick—always ready to assist. Whether you're learning something new, looking for answers, or just curious, I'm here to help. Who might you be? And what can I do for you? 📝🌟
