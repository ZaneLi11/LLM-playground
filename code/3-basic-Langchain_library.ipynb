# %%
from langchain_ollama import OllamaLLM

model = OllamaLLM(model = "deepseek-r1:8b")

response = model.invoke(input="who are u?")

print(response)
# Out:
# Hi there! 😊 I'm DeepSeek-R1, your friendly AI assistant created by DeepSeek. I'm here to help you with all sorts of things—whether that's answering questions, solving problems, helping with learning, or just chatting. You can think of me as a super excited, super helpful companion ready to dive into anything you need!
#
# So, what can I help you with today? 💬✨

# %%
import os
from dotenv import load_dotenv

from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
gemini_api_key = os.getenv("GEMINI_API_KEY")

if not gemini_api_key:
    raise ValueError("Can't find GEMINI_API_KEY")

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    google_api_key=gemini_api_key
)

response = model.invoke("who are u?")


print(response.content)
# Out:
# I am a large language model, trained by Google.
#
# My purpose is to assist you by providing information, generating text, answering questions, and engaging in helpful conversations. I don't have personal experiences, feelings, consciousness, or a physical body.

# %%
model = OllamaLLM(model = "deepseek-r1:8b")

response = model.stream(input="Could you list Top 10 research universities around the world?")

for chunk in response:
    print(chunk, end = "", flush=True)
# Out:
# Okay, here is a list of universities frequently appearing at or near the top in reputable global university rankings (like the QS World University Rankings and the Times Higher Education World University Rankings) for research excellence.
#
# It's important to remember that rankings can vary slightly between different methodologies and years, and "top 10" can be subjective. However, these institutions consistently feature prominently:
#
# 1.  **Massachusetts Institute of Technology (MIT)** - Widely considered the leader in many scientific and technological fields.
# 2.  **Harvard University** - Strong across a vast range of disciplines (STEM, humanities, social sciences, business).
# 3.  **Stanford University** - Particularly strong in technology, medicine, and the humanities, benefiting from its location near Silicon Valley.
# 4.  **Caltech (California Institute of Technology)** - Extremely strong in STEM, especially physics, engineering, and astronomy, known for its intimate community and research focus.
# 5.  **University of Cambridge** - Consistently ranked very highly, particularly strong in sciences, mathematics, humanities, and social sciences.
# 6.  **University of Oxford** - One of the oldest universities globally, consistently ranked very highly across a wide range of subjects.
# 7.  **ETH Zurich (Swiss Federal Institute of Technology)** - Dominant in engineering and natural sciences in Europe.
# 8.  **Princeton University** - Excellent across the board, particularly noted for its rigorous undergraduate and graduate programs in STEM and the social sciences.
# 9.  **University of Chicago** - Known for its strong emphasis on social science, economics, and physics, alongside its prestigious Booth School of Business.
# 10. **University of California, Berkeley (UC Berkeley)** - One of the world's leading public research universities, exceptionally strong in a wide range of fields including engineering, sciences, social sciences, and humanities.
#
# ## Key Factors in These Rankings
#
# *   **Research Output:** Citations, research impact, quantity of research.
# *   **Reputation:** Expert opinion surveys.
# *   **Academic Staff:** Quality and citations of professors.
# *   **Employer Reputation:** How highly graduates are regarded by employers.
# *   **Faculty Resources:** Student-to-faculty ratio, etc.
#
# This list provides a solid starting point for identifying institutions with outstanding research profiles worldwide.

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    google_api_key=gemini_api_key
)

response = model.stream("Could you list Top 10 research universities in US?")


for chunk in response:
    print(chunk.content, end="", flush=True)
# Out:
# It's important to note that "top" rankings can vary depending on the methodology used (e.g., research output, faculty reputation, funding, citations, student selectivity, etc.). However, here's a list of universities consistently recognized as leading research institutions in the US, often appearing in the top echelons of major national and international rankings (like U.S. News & World Report, QS, Times Higher Education, ARWU/Shanghai Ranking):
#
# 1.  **Princeton University**
# 2.  **Massachusetts Institute of Technology (MIT)**
# 3.  **Harvard University**
# 4.  **Stanford University**
# 5.  **Yale University**
# 6.  **University of Chicago**
# 7.  **Johns Hopkins University**
# 8.  **University of Pennsylvania**
# 9.  **California Institute of Technology (Caltech)**
# 10. **Duke University** (often tied with Northwestern University, Columbia University)
#
# **Important Considerations:**
#
# *   **Ties are common:** Many ranking systems will have ties, especially in the top 10. For example, Duke, Northwestern, and Columbia often vie for these spots or tie with others.
# *   **Public University Powerhouses:** While many of the above are private, major public universities like the **University of California, Berkeley** and the **University of California, Los Angeles (UCLA)** are also world-renowned research powerhouses and frequently rank just outside or sometimes within the top 10 depending on the specific ranking and its emphasis.
# *   **Specialization:** Some universities are particularly dominant in specific research fields (e.g., Johns Hopkins in medicine, Caltech in science/engineering).
# *   **Methodology Matters:** Always check the methodology of any ranking to understand what criteria are being prioritized.
#
# This list provides a strong overview of institutions consistently recognized for their immense research contributions and academic excellence.
