# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_ollama import OllamaLLM

chat_prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system","you are a teacher"),
        MessagesPlaceholder("history"),
        ("human","what's the relation between those 2 equations?"),
    ]
)

history_data = [
    ("human","whats the result of 2*9?"),
    ("ai","2*9=18"),
    ("human","whats the result of 18/2?"),
    ("ai","18/2=9"),
]

prompt = chat_prompt_template.invoke({"history":history_data})

model = OllamaLLM(
    model="deepseek-r1:8b"
)

response = model.invoke(prompt)

print(response)
# Out:
# The two equations are related through the inverse operation. In the first equation, multiplication (2 × 9 = 18) is used. The second equation involves division (18 ÷ 2 = 9), which is the inverse operation of multiplication. Specifically, dividing the product by one of the factors (2) gives back the other factor (9). This demonstrates how multiplication and division are inverse operations, where one operation can "undo" the effect of the other.
