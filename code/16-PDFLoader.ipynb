# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader(
    file_path="./data/Artical2_Zizheng_Li.pdf",
    mode="page",
    # password="lzz"
)
for doc in loader.lazy_load():
    print(doc)
# Out:
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 18 0 (offset 0)
# page_content='Zizheng Li Macy’s Accounting 1. What did the employee do and how did it impact Macy’s reported ﬁnancial performance? According to the article, a Macy’s employee intentionally failed to record approximately $154 million in delivery-related expenses over multiple years. By not recognizing these costs, Macy’s operating expenses were understated, which made the company’s reported proﬁts appear stronger than they actually were. As a result, Macy’s ﬁnancial performance looked better in prior reporting periods than it should have been, even though the underlying business performance had not changed.   2. What percent of the recorded delivery expenses was not recognized? The article states that Macy’s recorded approximately $4.36 billion in delivery expenses during the relevant period, while about $154 million was not recognized. This means roughly 3.5% of delivery expenses were omitted from the ﬁnancial statements. Although the percentage seems small, the dollar amount is material and signiﬁcant for investors.  3. Did it appear that the employee ﬁnancially beneﬁtted from the accounting action? Based on the information in the article, there is no indication that the employee personally proﬁted from the accounting omission. Macy’s stated that the individual did not receive ﬁnancial gain, suggesting that the issue was related more to internal control failures than personal fraud or embezzlement.   4. What concerns do investors have? Investors are concerned about the reliability of Macy’s ﬁnancial statements and internal controls. Even though the company stated that the error did not aLect cash ﬂow, the fact that such a large expense went unrecorded for several years raises questions about' metadata={'producer': 'macOS Version 15.3 (Build 24D2059) Quartz PDFContext', 'creator': 'PyPDF', 'creationdate': "D:20260128151354Z00'00'", 'moddate': "D:20260128151354Z00'00'", 'source': './data/Artical2_Zizheng_Li.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
# page_content='management oversight, accounting processes, and the accuracy of prior earnings reports. This can damage investor trust and increase uncertainty about future disclosures.   5. What methods might a company use to avoid this type of accounting omission? To prevent this type of issue, a company could strengthen internal controls by: 1. Requiring multiple levels of review for expense recognition 2. Implementing automated accounting systems with built-in reconciliation checks 3. Separating duties so no single employee controls the full expense-reporting process 4. Conducting more frequent internal audits These steps reduce the risk that large expenses go unnoticed or unreported for extended periods.  6. What aspect of the accounting profession might contribute to Macy’s being the latest (but not the only) company with ﬁnancial statement issues? One contributing factor is the growing complexity and pressure within the accounting profession. Companies operate at large scale with high transaction volumes, tight reporting deadlines, and increasing reliance on automated systems. This environment can make it easier for errors to persist if internal controls are weak. Additionally, staLing shortages and cost pressures within accounting departments may reduce oversight, making companies like Macy’s more vulnerable to reporting issues.' metadata={'producer': 'macOS Version 15.3 (Build 24D2059) Quartz PDFContext', 'creator': 'PyPDF', 'creationdate': "D:20260128151354Z00'00'", 'moddate': "D:20260128151354Z00'00'", 'source': './data/Artical2_Zizheng_Li.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}

# %%
from langchain_community.document_loaders import PyMuPDFLoader

# %%
loader = PyMuPDFLoader(
    file_path="./data/Artical2_Zizheng_Li.pdf",
    mode="page",
    # password="lzz"
)
i = 0
for doc in loader.lazy_load():
    print(doc)
    i = i + 1
    print(i)
# Out:
# page_content='Zizheng Li
# Macy’s Accounting
# 1. What did the employee do and how did it impact Macy’s reported
# ﬁnancial performance?
# According to the article, a Macy’s employee intentionally failed to record approximately
# $154 million in delivery-related expenses over multiple years. By not recognizing these
# costs, Macy’s operating expenses were understated, which made the company’s reported
# proﬁts appear stronger than they actually were. As a result, Macy’s ﬁnancial performance
# looked better in prior reporting periods than it should have been, even though the
# underlying business performance had not changed.
#
# 2. What percent of the recorded delivery expenses was not recognized?
# The article states that Macy’s recorded approximately $4.36 billion in delivery expenses
# during the relevant period, while about $154 million was not recognized. This means
# roughly 3.5% of delivery expenses were omitted from the ﬁnancial statements. Although
# the percentage seems small, the dollar amount is material and signiﬁcant for investors.
#
# 3. Did it appear that the employee ﬁnancially beneﬁtted from the
# accounting action?
# Based on the information in the article, there is no indication that the employee personally
# proﬁted from the accounting omission. Macy’s stated that the individual did not receive
# ﬁnancial gain, suggesting that the issue was related more to internal control failures than
# personal fraud or embezzlement.
#
# 4. What concerns do investors have?
# Investors are concerned about the reliability of Macy’s ﬁnancial statements and internal
# controls. Even though the company stated that the error did not aLect cash ﬂow, the fact
# that such a large expense went unrecorded for several years raises questions about' metadata={'producer': 'macOS Version 15.3 (Build 24D2059) Quartz PDFContext', 'creator': '', 'creationdate': "D:20260128151354Z00'00'", 'source': './data/Artical2_Zizheng_Li.pdf', 'file_path': './data/Artical2_Zizheng_Li.pdf', 'total_pages': 2, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20260128151354Z00'00'", 'trapped': '', 'modDate': "D:20260128151354Z00'00'", 'creationDate': "D:20260128151354Z00'00'", 'page': 0}
# 1
# page_content='management oversight, accounting processes, and the accuracy of prior earnings reports.
# This can damage investor trust and increase uncertainty about future disclosures.
#
# 5. What methods might a company use to avoid this type of accounting
# omission?
# To prevent this type of issue, a company could strengthen internal controls by:
# 1. Requiring multiple levels of review for expense recognition
# 2. Implementing automated accounting systems with built-in reconciliation checks
# 3. Separating duties so no single employee controls the full expense-reporting process
# 4. Conducting more frequent internal audits
# These steps reduce the risk that large expenses go unnoticed or unreported for extended
# periods.
#
# 6. What aspect of the accounting profession might contribute to Macy’s
# being the latest (but not the only) company with ﬁnancial statement
# issues?
# One contributing factor is the growing complexity and pressure within the accounting
# profession. Companies operate at large scale with high transaction volumes, tight reporting
# deadlines, and increasing reliance on automated systems. This environment can make it
# easier for errors to persist if internal controls are weak. Additionally, staLing shortages and
# cost pressures within accounting departments may reduce oversight, making companies
# like Macy’s more vulnerable to reporting issues.' metadata={'producer': 'macOS Version 15.3 (Build 24D2059) Quartz PDFContext', 'creator': '', 'creationdate': "D:20260128151354Z00'00'", 'source': './data/Artical2_Zizheng_Li.pdf', 'file_path': './data/Artical2_Zizheng_Li.pdf', 'total_pages': 2, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20260128151354Z00'00'", 'trapped': '', 'modDate': "D:20260128151354Z00'00'", 'creationDate': "D:20260128151354Z00'00'", 'page': 1}
# 2
