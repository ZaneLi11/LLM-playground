# %%
import json

d = {
    "name": "Kai Wang",
    "age": 23,
    "gender": "male"
}

s = json.dumps(d, ensure_ascii= False)

print(s)
# Out:
# {"name": "Kai Wang", "age": 23, "gender": "male"}

# %%
l = [
    {
        "name": "Zizheng Li",
        "age": 22,
        "gender": "male"
    },
    {
        "name": "Kai Wang",
        "age": 23,
        "gender": "male"
    },
    {
        "name": "Yue Wang",
        "age": 24,
        "gender": "female"
    }
]
print(json.dumps(l,ensure_ascii=False))
# Out:
# [{"name": "Zizheng Li", "age": 22, "gender": "male"}, {"name": "Kai Wang", "age": 23, "gender": "male"}, {"name": "Yue Wang", "age": 24, "gender": "female"}]

# %%
json_str = '{"name": "Kai Wang", "age": 23, "gender": "male"}'

# %%
json_arr_str = '[{"name": "Zizheng Li", "age": 22, "gender": "male"}, {"name": "Kai Wang", "age": 23, "gender": "male"}, {"name": "Yue Wang", "age": 24, "gender": "female"}]'

# %%
a = json.loads(json_str)
b = json.loads(json_arr_str)
print(a,type(a))
print(b,type(b))
# Out:
# {'name': 'Kai Wang', 'age': 23, 'gender': 'male'} <class 'dict'>
# [{'name': 'Zizheng Li', 'age': 22, 'gender': 'male'}, {'name': 'Kai Wang', 'age': 23, 'gender': 'male'}, {'name': 'Yue Wang', 'age': 24, 'gender': 'female'}] <class 'list'>
